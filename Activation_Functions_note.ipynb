# %% [markdown]
# <a href="https://colab.research.google.com/github/yeabwang/tensorflow/blob/main/Activation_Functions_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Sigmoid Functions
#
# * Range: The output values are between 0 and 1, making it useful for probability estimation.
# * Smooth and Differentiable: The function is continuous and has a well-defined derivative.
# * Used in binary classification problems.
# * Applied in the output layer of logistic regression.
# * S-shaped (Sigmoidal) Curve: The function is symmetric around
# 𝑥
# =
# 0
# x=0, where
# 𝜎
# (
# 0
# )
# =0.5
# σ(0)=0.5.
# * Gradient Vanishing Issue: For very large or very small
# 𝑥
# x, the derivative approaches zero, leading to slow learning in deep networks.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SoftMax
#
# The Softmax function is an activation function used primarily in multi-class classification problems. It converts a vector of raw scores (logits) into probabilities that sum to 1.
#
# Properties of Softmax
# * Range: Outputs are in the range (0,1).
# * Sum to One: Ensures valid probability distribution.
# * Amplifies Differences: Larger input values get higher probabilities.
# * Sensitive to Scale: Large input values can cause numerical instability (can be mitigated by subtracting
# max
# ⁡
# (
# 𝑥
# )
# max(x) before exponentiation).
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tanh
#
# It is a smoother, zero-centered alternative to the sigmoid function, producing outputs between -1 and 1.
#
# Properties
# * Range:
# −
# 1
# ≤
# tanh
# ⁡
# (
# 𝑥
# )
# ≤
# 1
# −1≤tanh(x)≤1.
# * S-shaped (sigmoidal) curve: Similar to the sigmoid function but centered at zero.
# * Zero-centered: Unlike sigmoid, tanh produces negative and positive values, helping reduce bias in network activations.
# * Smooth and differentiable: The function is continuous and has a well-defined derivative.
# * Gradient vanishing issue: For very large or very small
# 𝑥
# x, the derivative approaches zero, slowing down learning in deep networks.
#
#
# When It’s Used
# * Hidden layers of neural networks: Preferred over sigmoid due to zero-centered output.
# * Recurrent Neural Networks (RNNs): Helps maintain a balance of positive and negative activations.
# * Normalization: Used in some normalization techniques due to its symmetric output.
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ReLU
#
# It introduces non-linearity by outputting the input directly if it's positive and zero otherwise.
#
# Properties
# * Range:
# 0
# ≤
# ReLU
# (
# 𝑥
# )
# <
# ∞
# 0≤ReLU(x)<∞.
# * Non-linear: Despite being a piecewise linear function, it enables deep networks to learn complex patterns.
# * Zero-centered output: No, since ReLU outputs only non-negative values.
# * Computationally efficient: Simple to compute compared to sigmoid and tanh.
# * Dying ReLU problem: If too many negative values occur, neurons can "die" (always output zero).
#
#
# When It’s Used
# * Deep Neural Networks (DNNs): Most commonly used in hidden layers of deep learning models.
# * CNNs (Convolutional Neural Networks): Preferred due to efficient computation and sparsity properties.
# * Generative models: Often used in certain GAN architectures.
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Leaky ReLU
#
# The Leaky ReLU function is a variant of ReLU that allows small negative values instead of zero for negative inputs. This helps avoid the "dying ReLU" problem, where neurons output zero and stop learning.
#
# Properties
# * Range:
# (
# −
# ∞
# ,
# ∞
# )
# (−∞,∞) (outputs negative values instead of zero).
# * Non-linear: Helps neural networks learn complex patterns.
# * Allows small negative outputs: Unlike standard ReLU, it keeps small gradients for negative inputs.
# * Computationally efficient: Similar to ReLU, requiring minimal computation.
# * No dead neurons: Because it assigns a small slope to negative inputs, neurons remain active.
#
# When It’s Used
# * Deep Neural Networks: Used when ReLU suffers from dying neurons.
# * Generative Models & GANs: Helps in learning fine details.
# * Speech Recognition & NLP: Used in some recurrent architectures where zero gradients are problematic.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Parametric ReLU
#
# The Parametric ReLU (PReLU) is a variant of the Leaky ReLU where the slope of the negative part of the function is learned during training, rather than being fixed as a constant. This allows the model to adapt and optimize the negative slope for different layers or neurons.
#
# Properties
# * Range:
# (
# −
# ∞
# ,
# ∞
# )
# (−∞,∞), similar to Leaky ReLU, with adaptable negative values.
# * Non-linear: Enables the network to learn complex representations.
# * Adaptable negative slope: The slope for
# 𝑥
# ≤
# 0
# x≤0 is learned during training, allowing more flexibility than Leaky ReLU.
# * Prevents dying neurons: The function allows negative values and adjusts the slope to avoid issues like the "dying ReLU."
# * Computationally efficient: Still efficient like ReLU, while providing flexibility to improve learning.
#
#
# When It’s Used
# * Deep Neural Networks (DNNs): Useful when needing more flexibility for learning activation functions.
# * Convolutional Neural Networks (CNNs): Can improve performance, especially when negative values are beneficial for certain features.
# * Generative Models: Often used in GANs to improve the learning of complex features.
# * Applications needing more adaptable activations: Where ReLU or Leaky ReLU might be too restrictive for specific layers or tasks.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## GELU
#
# The GELU (Gaussian Error Linear Unit) is an activation function that approximates the cumulative distribution function (CDF) of the standard normal distribution. It combines the benefits of ReLU and the smoothness of sigmoid or tanh, providing a smoother transition for values near zero.
#
# Properties
# * Range: The output range is similar to ReLU, but it is continuous and smooth, without sharp boundaries.
# * Smooth and differentiable: The function is continuous and has well-defined derivatives at every point.
# * Non-monotonic: Unlike ReLU and Leaky ReLU, GELU has a smooth, non-monotonic curve.
# * Probabilistic interpretation: GELU can be interpreted as applying a probability threshold (related to the standard normal distribution) to decide whether an activation should be passed or not.
# * Computationally more expensive than ReLU: It involves a more complex formula compared to simpler activation functions like ReLU or Leaky ReLU.
#
# When It’s Used
# * Transformer Models (e.g., BERT): GELU has been found to perform well in transformer architectures, where its smoothness and probabilistic nature help in handling complex features.
# * Deep Learning Networks: Can be used in any deep neural network where smoother activations might help with training dynamics.
# * NLP and Sequence Models: Popular in natural language processing (NLP) models, particularly in transformer-based models, for better representation learning.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Sigmoid Linear Unit (SILU)
#
# The Sigmoid Linear Unit (SiLU), also known as the Swish activation function, is an activation function that combines the sigmoid function with the identity function (linear). It has been shown to outperform ReLU in certain deep learning tasks, providing a smooth, non-monotonic curve that helps neural networks converge faster. The function is differentiable, continuous, and avoids the "dying ReLU" problem.
#
#
# Properties
# * Range: The output range is
# (
# −
# ∞
# ,
# ∞
# )
# (−∞,∞), making it more flexible than functions like ReLU or tanh.
# * Smooth and differentiable: It is a smooth, continuous function that avoids sharp corners, unlike ReLU and its variants.
# * Non-monotonic: Unlike functions like ReLU, SiLU has a smooth curve, allowing for a more natural gradient during backpropagation.
# * Computationally efficient: While slightly more expensive than ReLU due to its sigmoid component, it is still efficient compared to other activation functions like tanh or GELU.
# * Helps with gradients: Unlike ReLU, which can "die" for negative inputs, SiLU allows gradients to flow for negative inputs, improving training stability.
#
# When It’s Used
# * Deep Learning Networks: SiLU is used in deep neural networks and has been shown to work better than ReLU in some tasks, especially in tasks that involve complex representations.
# * Convolutional Neural Networks (CNNs): It can be used in CNNs to enhance learning in deeper layers.
# * Transformer-based Models: In natural language processing (NLP), especially in transformers, SiLU can help speed up training and improve convergence.
# * When ReLU and tanh face limitations: SiLU is a good choice when models face issues with non-monotonicity or the dying neuron problem of ReLU.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exponential Linear Unit
#
# The Exponential Linear Unit (ELU) activation function is designed to solve some of the limitations of ReLU by introducing a smooth curve for negative values. It combines the properties of both ReLU and exponential functions, allowing for a non-zero output for negative inputs, helping to avoid issues like "dead neurons" (as seen in ReLU). ELU introduces an exponential component for negative inputs, which helps in maintaining a positive mean activation and improving learning dynamics.
#
# Properties
# * Range: The output range is
# (
# −
# ∞
# ,
# ∞
# )
# (−∞,∞). For positive values of
# 𝑥
# x, it behaves like the identity function (just
# 𝑥
# x). For negative values of
# 𝑥
# x, the output is negative but bounded below by a value determined by the parameter
# 𝛼
# α.
# * Smoother: ELU is smoother than ReLU and sigmoid-based functions, providing a continuous, differentiable output, which aids in better gradient flow.
# * Prevents dead neurons: Unlike ReLU, which can lead to dead neurons when the output is zero for negative inputs, ELU maintains negative outputs for negative values, improving learning stability.
# * Learning dynamics: ELU introduces a shifted output that helps maintain a zero-centered distribution for the activations, potentially speeding up training and leading to better convergence in deep networks.
# * Computationally more expensive: ELU involves exponential calculations for negative inputs, which makes it slightly more computationally expensive compared to ReLU.
#
#
# When It’s Used
# * Deep Networks: ELU is used in deeper neural networks where the vanishing gradient problem (often seen with sigmoid or tanh) and the dying neuron problem (with ReLU) are concerns. It offers a good alternative, ensuring that gradients flow well during training.
# * Convolutional Neural Networks (CNNs): It can be used in CNNs, especially for image classification tasks, where smooth transitions and non-zero-centered activations can enhance training.
# * Generative Models: ELU can be useful in generative models like variational autoencoders or generative adversarial networks (GANs) due to its smooth activation profile.
# * When Zero-Centered Activations are Needed: Since ELU produces activations that are zero-centered (especially with
# 𝛼
# =
# 1
# α=1), it’s helpful in tasks where maintaining a mean zero activation is important for better convergence and optimization.
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
